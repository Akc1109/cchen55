# %% [markdown]
# <a href="https://colab.research.google.com/github/cchen55/cchen55/blob/master/InClass0822.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# load the dataset

# %%
PATH = 'http://optimizizer.com/data/'

# %%
hands = pd.read_csv(PATH + "game-data-516.csv")

# %%
PATH + "game-data-516.csv"
# Out:
# 'http://optimizizer.com/data/game-data-516.csv'

# %%
hands.columns
# Out:
# Index(['timeid', 'name', 'gender', 'pcard', 'ccard', 'position', 'paction',
#        'caction', 'outcome'],
#       dtype='object')

# %%
hands.name.unique()
# Out:
# array(['Jeremy', 'Gui', 'Tanner', 'CHEN', 'Hayley Coughlin', 'Ebi',
#        'Alaina A.', 'Rutvik Sule', 'Brenna', 'Patrick', 'AVINASH',
#        'Justin Drake', nan], dtype=object)

# %%
hands[ hands.name == "Rutvik Sule"]
# Out:
#              timeid         name gender pcard  ... position paction caction outcome
# 31   20190822115429  Rutvik Sule   male  king  ...    first     bet    call      -2
# 67   20190822115504  Rutvik Sule   male  king  ...   second    call     bet      -2
# 86   20190822115521  Rutvik Sule   male  king  ...    first    stay    stay      -1
# 110  20190822115537  Rutvik Sule   male  king  ...   second    fold     bet      -1
# 130  20190822115554  Rutvik Sule   male  king  ...    first    stay    stay      -1
# 147  20190822115604  Rutvik Sule   male  king  ...   second    call     bet      -2
# 159  20190822115612  Rutvik Sule   male  king  ...    first    stay    stay      -1
# 167  20190822115620  Rutvik Sule   male  king  ...   second    fold     bet      -1
# 189  20190822115635  Rutvik Sule   male  king  ...    first     bet    call      -2
# 219  20190822115653  Rutvik Sule   male  king  ...   second    call     bet      -2
# ...

# %%
names = pd.read_csv(PATH + "names.csv")

# %%
names.head()
# Out:
#    id       name sex  births  year
# 0   0       Mary   F    7065  1880
# 1   1       Anna   F    2604  1880
# 2   2       Emma   F    2003  1880
# 3   3  Elizabeth   F    1939  1880
# 4   4     Minnie   F    1746  1880

# %%
names.tail()
# Out:
#               id    name sex  births  year
# 1858684  1858684  Zykell   M       5  2015
# 1858685  1858685  Zyking   M       5  2015
# 1858686  1858686   Zykir   M       5  2015
# 1858687  1858687   Zyrus   M       5  2015
# 1858688  1858688    Zyus   M       5  2015

# %%
# names.year.unique()
names[((names.name=="John") | (names.name=="Jim")) & (names.year > 1990)]
# Out:
#               id  name sex  births  year
# 1096338  1096338  John   F      63  1991
# 1109686  1109686  John   M   27798  1991
# 1110432  1110432   Jim   M     183  1991
# 1121655  1121655  John   F      56  1992
# 1134943  1134943  John   M   26241  1992
# 1135671  1135671   Jim   M     194  1992
# 1146762  1146762  John   F      69  1993
# 1160554  1160554  John   M   24989  1993
# 1161358  1161358   Jim   M     167  1993
# 1173303  1173303  John   F      48  1994
# 1186469  1186469  John   M   24175  1994
# 1187266  1187266   Jim   M     170  1994
# 1199398  1199398  John   F      45  1995
# 1212466  1212466  John   M   23232  1995
# 1213314  1213314   Jim   M     158  1995
# 1225954  1225954  John   F      37  1996
# 1238683  1238683  John   M   22169  1996
# 1239543  1239543   Jim   M     157  1996
# 1253046  1253046  John   F      29  1997
# 1265371  1265371  John   M   21372  1997
# 1266351  1266351   Jim   M     130  1997
# 1280343  1280343  John   F      27  1998
# ...

# %%
names.columns
# Info
# Out:
# Index(['id', 'name', 'sex', 'births', 'year'], dtype='object')

# %%
names.shape
# Out:
# (1858689, 5)

# %%
nrows = names.shape[0]
ncols = names.shape[1]

# %%
nrows
# Out:
# 1858689

# %%
ncols
# Out:
# 5
